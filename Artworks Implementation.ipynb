# %% [markdown]
# <img src="https://editor.analyticsvidhya.com/uploads/521138.png"> </img>
#
# ## VGG-11 is a convolutional neural network that specializes in processing images

# %% [markdown]
# ## Using VGG-11 to suggest art pieces in a similar style
#
# Given an image that you like, can we suggest pieces in a similar style? Note that this is slightly different than "given an image, can we offer images that look the same"

# %%
import torchvision.models as models
import torch.nn as nn
import torch
import matplotlib.pyplot as plt
import torch.optim as optim
import numpy as np
import pandas as pd
import os
import torch
from torch.utils.data import Dataset
from skimage import io

# %%
class Artist(Dataset):
    def __init__(self,csv_file,root_dir,transform=None):
        self.annotations=pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform
        
        
    def __len__(self):
        return len(self.annotations)
    
    def __getitem__(self, index):
        img_path = os.path.join(self.root_dir, self.annotations.iloc[index,0])
        image=io.imread(img_path)
        y_label=torch.tensor(int(self.annotations.iloc[index,1]))
        
        if self.transform:
            augmentations = self.transform(image=image)
            image = augmentations["image"]

            
        return(image,y_label)

# %%
# fine tune on style and use bert to vectorize the style name to branch out of style as well??

# %%
from torchvision import transforms, datasets
from torch.utils.data import DataLoader

import albumentations as A
from albumentations.pytorch import ToTensorV2

device = torch.device('mps' if torch.backends.mps.is_available() else 'cpu')
print(torch.backends.mps.is_available())

#_transforms = transforms.Compose(
#[
 #   transforms.Resize((224, 224)),
  #  transforms.ToTensor(),
   # transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # standardization of pixel colors
#])
_transforms = A.Compose([
    A.Resize(width=224, height=224,),
    A.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225],
    ),
    ToTensorV2(),
])


#train_dataset = datasets.ImageFolder(root='/Users/abdelrahmanelbialy/Desktop/wikiart/splitted_wikiart_dataset/train', transform=_transforms)
#test_dataset = datasets.ImageFolder(root='/Users/abdelrahmanelbialy/Desktop/wikiart/splitted_wikiart_dataset/test', transform=_transforms)

train_dataset = Artist(csv_file='/Users/abdelrahmanelbialy/Desktop/wikiart/wikiart_csv/artist_train.csv',root_dir='/Users/abdelrahmanelbialy/Desktop/wikiart/wikiartdataset',transform=_transforms)
test_dataset = Artist(csv_file='/Users/abdelrahmanelbialy/Desktop/wikiart/wikiart_csv/artist_test.csv',root_dir='/Users/abdelrahmanelbialy/Desktop/wikiart/wikiartdataset',transform=_transforms)


batch_size = 256

training_dataloader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
testing_dataloader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=True)
# Out:
# True

# %%
#len(train_dataset) + len(test_dataset)
train_dataset.__len__()+test_dataset.__len__()
# Out:
# 19048

# %%
images, labels = next(iter(training_dataloader)) 
images.shape, labels.shape
# Out:
# (torch.Size([256, 3, 224, 224]), torch.Size([256]))

# %%
plt.imshow(images[0].detach().numpy().transpose(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
vgg_model = models.vgg11(weights=models.VGG11_Weights.IMAGENET1K_V1)
vgg_model.classifier[-1].out_features
vgg_model.to(device)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU(inplace=True)
#     (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU(inplace=True)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): ReLU(inplace=True)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
vgg_model.classifier
# Out:
# Sequential(
#   (0): Linear(in_features=25088, out_features=4096, bias=True)
#   (1): ReLU(inplace=True)
#   (2): Dropout(p=0.5, inplace=False)
#   (3): Linear(in_features=4096, out_features=4096, bias=True)
#   (4): ReLU(inplace=True)
#   (5): Dropout(p=0.5, inplace=False)
#   (6): Linear(in_features=4096, out_features=23, bias=True)
# )

# %%
vgg_model.classifier[-1] = nn.Linear(4096 ,23, device='mps')  # Change the final classifier layer to output 10 classes instead of 1,000

for layer in vgg_model.classifier:  # Randomize all parameters in the classifier to start fresh
    if hasattr(layer, 'weight'):  # Randomize all parameters in the classifier to start fresh
        torch.nn.init.xavier_uniform_(layer.weight)  # Randomize all parameters in the classifier to start fresh
    if hasattr(layer, 'bias'):  # Randomize all parameters in the classifier to start fresh
        nn.init.constant_(layer.bias.data, 0)  # Randomize all parameters in the classifier to start fresh

vgg_model.classifier[-1].out_features
# Out:
# 23

# %%
criterion = nn.CrossEntropyLoss() 
optimizer = optim.SGD(vgg_model.parameters(), lr=0.007, momentum=0.9)

n_epochs = 20 
print_every = 50
valid_loss_min = np.Inf
total_step = len(training_dataloader)

train_loss, val_loss, train_acc, val_acc = [], [], [], []

# %%
# code inspired from https://www.pluralsight.com/guides/introduction-to-resnet


vgg_model.train()

for epoch in range(1, n_epochs + 1):
    running_loss = 0.0
    correct = 0
    total=0
    print(f'Epoch {epoch}\n')
    for batch_idx, (data_, target_) in enumerate(training_dataloader):
        data_, target_ = data_.to(device), target_.to(device)
        
        optimizer.zero_grad()  # clears the gradient or else they accumulate
        
        outputs = vgg_model(data_)
        
        loss = criterion(outputs, target_)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, pred = torch.max(outputs, dim=1)
        correct += torch.sum(pred==target_).item()
        total += target_.size(0)
        if (batch_idx) % print_every == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch, n_epochs, batch_idx, total_step, loss.item()))
    train_acc.append(100 * correct / total)
    train_loss.append(running_loss/total_step)
    print(f'\ntrain-loss: {np.mean(train_loss):.4f}, train-acc: {(100 * correct/total):.4f}%')
    
    batch_loss = 0
    total_t=0
    correct_t=0
    with torch.no_grad():
        vgg_model.eval()
        for data_t, target_t in (testing_dataloader):
            data_t, target_t = data_t.to(device), target_t.to(device)
            outputs_t = vgg_model(data_t)
            loss_t = criterion(outputs_t, target_t)
            batch_loss += loss_t.item()
            _, pred_t = torch.max(outputs_t, dim=1)
            correct_t += torch.sum(pred_t==target_t).item()
            total_t += target_t.size(0)
        val_acc.append(100 * correct_t/total_t)
        val_loss.append(batch_loss/len(testing_dataloader))
        network_learned = batch_loss < valid_loss_min
        print(f'validation loss: {np.mean(val_loss):.4f}, validation acc: {(100 * correct_t/total_t):.4f}%\n')

        if network_learned:
            valid_loss_min = batch_loss
            torch.save(vgg_model.state_dict(), 'vgg11_9_wikiart.pt')
            print('Saving Parameters')
            
    vgg_model.train()
    
# A set device to either cuda or cpu2
# Out:
# Epoch 1
#
# Epoch [1/20], Step [0/53], Loss: 4.2448
# Epoch [1/20], Step [50/53], Loss: 1.9442
#
# train-loss: 2.5354, train-acc: 26.0661%
# validation loss: 1.8559, validation acc: 44.1543%
#
# Saving Parameters
# Epoch 2
#
# Epoch [2/20], Step [0/53], Loss: 1.9799
# Epoch [2/20], Step [50/53], Loss: 1.5379
#
# train-loss: 2.0942, train-acc: 50.6108%
# validation loss: 1.6175, validation acc: 58.3874%
#
# Saving Parameters
# Epoch 3
#
# Epoch [3/20], Step [0/53], Loss: 1.4886
# Epoch [3/20], Step [50/53], Loss: 1.2733
#
# train-loss: 1.8158, train-acc: 61.7927%
# validation loss: 1.4509, validation acc: 66.1700%
#
# Saving Parameters
# Epoch 4
#
# Epoch [4/20], Step [0/53], Loss: 0.9946
# Epoch [4/20], Step [50/53], Loss: 1.1401
#
# train-loss: 1.6069, train-acc: 70.0517%
# validation loss: 1.4369, validation acc: 59.4741%
#
# Epoch 5
#
# Epoch [5/20], Step [0/53], Loss: 1.1868
# Epoch [5/20], Step [50/53], Loss: 0.9742
#
# train-loss: 1.4565, train-acc: 73.7091%
# validation loss: 1.3552, validation acc: 69.2726%
#
# Saving Parameters
# Epoch 6
#
# Epoch [6/20], Step [0/53], Loss: 0.7407
# Epoch [6/20], Step [50/53], Loss: 0.6712
#
# train-loss: 1.3127, train-acc: 81.4659%
# validation loss: 1.2803, validation acc: 73.9877%
#
# Saving Parameters
# Epoch 7
#
# Epoch [7/20], Step [0/53], Loss: 0.6392
# Epoch [7/20], Step [50/53], Loss: 0.5404
#
# train-loss: 1.1889, train-acc: 85.8203%
# validation loss: 1.2350, validation acc: 73.4969%
#
# Epoch 8
#
# Epoch [8/20], Step [0/53], Loss: 0.3927
# Epoch [8/20], Step [50/53], Loss: 0.3904
#
# train-loss: 1.0953, train-acc: 86.0676%
# validation loss: 1.1845, validation acc: 76.3891%
#
# Saving Parameters
# Epoch 9
#
# Epoch [9/20], Step [0/53], Loss: 0.2471
# Epoch [9/20], Step [50/53], Loss: 0.2917
#
# train-loss: 1.0057, train-acc: 90.7742%
# validation loss: 1.1678, validation acc: 74.0929%
#
# Epoch 10
#
# Epoch [10/20], Step [0/53], Loss: 0.3072
# Epoch [10/20], Step [50/53], Loss: 0.1215
#
# train-loss: 0.9268, train-acc: 93.0076%
# validation loss: 1.1501, validation acc: 76.4417%
#
# Epoch 11
#
# Epoch [11/20], Step [0/53], Loss: 0.2381
# Epoch [11/20], Step [50/53], Loss: 0.1712
#
# train-loss: 0.8579, train-acc: 94.3941%
# validation loss: 1.1309, validation acc: 77.1429%
#
# Epoch 12
#
# Epoch [12/20], Step [0/53], Loss: 0.1379
# Epoch [12/20], Step [50/53], Loss: 0.0435
#
# train-loss: 0.7945, train-acc: 96.8598%
# validation loss: 1.1196, validation acc: 77.5811%
#
# Epoch 13
#
# Epoch [13/20], Step [0/53], Loss: 0.0854
# Epoch [13/20], Step [50/53], Loss: 0.0441
#
# train-loss: 0.7386, train-acc: 97.8491%
# validation loss: 1.1150, validation acc: 77.7739%
#
# Epoch 14
#
# Epoch [14/20], Step [0/53], Loss: 0.0285
# Epoch [14/20], Step [50/53], Loss: 0.0725
#
# train-loss: 0.6898, train-acc: 98.2613%
# validation loss: 1.1086, validation acc: 78.6152%
#
# Epoch 15
#
# Epoch [15/20], Step [0/53], Loss: 0.0602
# Epoch [15/20], Step [50/53], Loss: 0.0802
#
# train-loss: 0.6484, train-acc: 97.6992%
# validation loss: 1.1048, validation acc: 79.0359%
#
# Epoch 16
#
# Epoch [16/20], Step [0/53], Loss: 0.0398
# Epoch [16/20], Step [50/53], Loss: 0.0548
#
# train-loss: 0.6105, train-acc: 98.5086%
# validation loss: 1.0993, validation acc: 79.5793%
#
# Epoch 17
#
# Epoch [17/20], Step [0/53], Loss: 0.0123
# Epoch [17/20], Step [50/53], Loss: 0.0134
#
# train-loss: 0.5770, train-acc: 98.7484%
# validation loss: 1.0985, validation acc: 78.8431%
#
# Epoch 18
#
# Epoch [18/20], Step [0/53], Loss: 0.0242
# Epoch [18/20], Step [50/53], Loss: 0.0197
#
# train-loss: 0.5465, train-acc: 99.0932%
# validation loss: 1.0959, validation acc: 78.9658%
#
# Epoch 19
#
# Epoch [19/20], Step [0/53], Loss: 0.0149
# Epoch [19/20], Step [50/53], Loss: 0.0122
#
# train-loss: 0.5190, train-acc: 99.2505%
# validation loss: 1.0963, validation acc: 78.9658%
#
# Epoch 20
#
# Epoch [20/20], Step [0/53], Loss: 0.0127
# Epoch [20/20], Step [50/53], Loss: 0.0339
#
# train-loss: 0.4943, train-acc: 99.1681%
# validation loss: 1.0981, validation acc: 78.8256%

# %%
plt.plot(val_loss)

# %%
plt.plot(val_acc)
plt.title('Testing Set Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy %')
# Out:
# Text(0, 0.5, 'Accuracy %')

# %% [markdown]
# ## 2 Weeks Later

# %%
# Load up our imports
import torchvision.models as models
import torch.nn as nn
import torch
import matplotlib.pyplot as plt
import numpy as np

# %%
# Instantiate a VGG model with our saved weights
vgg_model = models.vgg11(weights=models.VGG11_Weights.IMAGENET1K_V1)  # B
vgg_model.classifier[-1] = nn.Linear(4096, 27)
vgg_model.load_state_dict(torch.load('/Users/abdelrahmanelbialy/Desktop/artworksdataset/vgg11_7_wikiart.pt'))

vgg_model.eval()
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU(inplace=True)
#     (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU(inplace=True)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): ReLU(inplace=True)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=27, bias=True)
#   )
# )

# %%
# re-loading the test dataset

batch_size = 32

testing_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %%
from tqdm import tqdm

testing_embeddings = torch.zeros(len(test_dataset), 512)
with torch.no_grad():
    for index, (batch, labels) in enumerate(tqdm(testing_dataloader)):
        testing_embeddings[index*batch_size:index*batch_size+batch.shape[0],:] = vgg_model.features(batch).mean((2, 3))
# Out:
# 100%|█████████████████████████████████████████| 531/531 [02:32<00:00,  3.48it/s]

# %%
testing_embeddings.shape
# Out:
# torch.Size([16963, 512])

# %%
from PIL import Image

img = Image.open('/Users/abdelrahmanelbialy/Desktop/artworksdataset/yiannis-tsaroychis_alain-as-summer-1976.jpg')
newsize = (300, 400)
img = img.resize(newsize)
img
# Out:
# <PIL.Image.Image image mode=RGB size=300x400>

# %%
img2 = Image.open('/Users/abdelrahmanelbialy/Desktop/artworksdataset/yiannis-tsaroychis_alain-as-winter-1975.jpg')
newsize = (300, 400)
img2 = img2.resize(newsize)
img2
# Out:
# <PIL.Image.Image image mode=RGB size=300x400>

# %%
_transforms = transforms.Compose(
[
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
   transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # standardization of pixel colors
])

image_matrix = np.asarray(np.expand_dims(_transforms(img), 0))
image2_matrix = np.asarray(np.expand_dims(_transforms(img2), 0))

plt.imshow(image_matrix[0].transpose(1, 2, 0))
plt.imshow(image2_matrix[0].transpose(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# style prediction
print(train_dataset.classes[vgg_model(torch.tensor(image_matrix)).argmax()])
print(train_dataset.classes[vgg_model(torch.tensor(image2_matrix)).argmax()])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[106], line 2
#       1 # style prediction
# ----> 2 print(train_dataset.classes[vgg_model(torch.tensor(image_matrix)).argmax()])
#       3 print(train_dataset.classes[vgg_model(torch.tensor(image2_matrix)).argmax()])
#
# AttributeError: 'Artist' object has no attribute 'classes'

# %%
similarity = torch.cosine_similarity(
    vgg_model.features(torch.tensor(image_matrix)).mean((2, 3)), 
    vgg_model.features(torch.tensor(image2_matrix)).mean((2, 3))
)

print(similarity)
# Out:
# tensor([0.8427], grad_fn=<SumBackward1>)

# %%
plt.figure()
f, axarr = plt.subplots(1, 5, figsize=(20, 10)) 
for index, top_image in enumerate(top_similar_images):
    axarr[index].imshow(test_dataset[top_image][0].detach().numpy().transpose(1, 2, 0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[86], line 3
#       1 plt.figure()
#       2 f, axarr = plt.subplots(1, 5, figsize=(20, 10))
# ----> 3 for index, top_image in enumerate(top_similar_images):
#       4     axarr[index].imshow(test_dataset[top_image][0].detach().numpy().transpose(1, 2, 0))
#
# NameError: name 'top_similar_images' is not defined

# %% [markdown]
# # Next Steps + Considersations
#
# 1. 100 x 100 is likely not big enough to capture style properly. This was done to make training easier on CPUs
# 2. It would behoove us to consolidate response to a number closer to 100-300 categories to make training easier
# 3. We can consider other deep learning models like Resnet and the Vision Transformer
